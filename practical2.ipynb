# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0           72             85             70               88       2023
# 1           65             80             68               82       2022
# 2           78             90             75               92       2024
# 3           69             83             71               86       2021
# 4           74             87             73               89       2023
# 5           62             79             65               80       2020
# 6           81             91             77               94       2024
# 7           70             84             72               88       2022
# 8           66             82             67               83       2021
# 9           75             88             74               90       2023
# 10          68             81             69               85       2020
# 11          79             92             76               95       2024
# 12          73             86             72               87       2022
# 13          64             78             66               81       2021
# 14          77             89             75               91       2023
# 15          71             83             70               86       2022
# 16          69             80             68               84       2021
# 17          76             90             74               92       2024
# 18          63             77             65               79       2020
# 19          82             93             78               95       2024
# 20          74             88             73               90       2023
# 21          67             82             69               84       2021
# 22          70             85             71               88       2022
# 23          78             91             76               93       2024
# 24          72             84             70               87       2023
# 25          66             81             67               83       2021
# 26          75             89             74               91       2024
# 27          69             83             70               86       2022
# 28          71             86             72               88       2023
# 29          73             87             73               89       2023
#
#     Placement_Offer
# 0                 3
# 1                 2
# 2                 3
# 3                 2
# 4                 3
# 5                 1
# 6                 3
# 7                 2
# 8                 2
# 9                 3
# 10                2
# 11                3
# 12                3
# 13                2
# 14                3
# 15                2
# 16                2
# 17                3
# 18                1
# 19                3
# 20                3
# 21                2
# 22                2
# 23                3
# 24                3
# 25                2
# 26                3
# 27                2
# 28                3
# 29                3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       30 non-null     int64
#  1   Reading_Score    30 non-null     int64
#  2   Writing_Score    30 non-null     int64
#  3   Placement_Score  30 non-null     int64
#  4   Club_Join        30 non-null     int64
#  5   Placement_Offer  30 non-null     int64
# dtypes: int64(6)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score    Club_Join  \
# count   30.000000      30.000000      30.000000        30.000000    30.000000
# mean    71.633333      85.133333      71.333333        87.533333  2022.333333
# std      5.288135       4.384403       3.546084         4.344901     1.321789
# min     62.000000      77.000000      65.000000        79.000000  2020.000000
# 25%     68.250000      82.000000      69.000000        84.250000  2021.000000
# 50%     71.500000      85.000000      71.500000        88.000000  2022.500000
# 75%     75.000000      88.750000      74.000000        90.750000  2023.000000
# max     82.000000      93.000000      78.000000        95.000000  2024.000000
#
#        Placement_Offer
# count        30.000000
# mean          2.466667
# std           0.628810
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
x= df.Math_Score.mean()

# %%
df['Math_Score'] = df['Math_Score'].fillna(x)

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
y = df.Writing_Score.mean()

# %%
y
# Out:
# np.float64(71.33333333333333)

# %%
df.Writing_Score.fillna(y,inplace= True)
# Out:
# C:\Users\unnat\AppData\Local\Temp\ipykernel_43752\3604612155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_Score.fillna(y,inplace= True)

# %%
df['Writing_Score'] = df['Writing_Score'].fillna(y)

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
z = df.Reading_Score.min()

# %%
df['Reading_Score'] = df['Reading_Score'].fillna(z)

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
a = df.Placement_Score.max()

# %%
df['Placement_Score'] = df['Placement_Score'].fillna(a)

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join', 'Placement_Offer'],
#       dtype='object')

# %%
df.boxplot(column=['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score'])
# Out:
# <Axes: >

# %%
import numpy as np
Q1 = np.percentile(df['Math_Score'], 25)
Q3 = np.percentile(df['Math_Score'], 75)

IQR = Q3 - Q1

# %%
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower Limit:", lower)
print("Upper Limit:", upper)
# Out:
# Lower Limit: 58.125
# Upper Limit: 85.125

# %%
outliers = df[(df['Math_Score'] < lower) | (df['Math_Score'] > upper)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join, Placement_Offer]
# Index: []

# %%
df = df.drop(df[(df['Math_Score'] < lower) | 
                (df['Math_Score'] > upper)].index)

# %%
import matplotlib.pyplot as plt

df.boxplot(column=['Math_Score',
                   'Reading_Score',
                   'Writing_Score',
                   'Placement_Score'])

plt.show()
